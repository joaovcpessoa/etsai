# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import urllib.request
import matplotlib.pyplot as plt
import tensorflow as tf

import cv2
from sklearn.model_selection import train_test_split

from keras.datasets import cifar10
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.models import Model, load_model
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Dropout, Flatten, BatchNormalization, Activation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(X_train, y_train_single), (X_test, y_test_single) = cifar10.load_data()

X_train, X_valid, y_train_single, y_valid_single = train_test_split(X_train, y_train_single, test_size=0.1, random_state=0)

print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train_single.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid_single.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test_single.shape)

X_train = X_train.astype('float32')
X_valid = X_valid.astype('float32')
X_test = X_test.astype('float32')

mean = np.mean(X_train, axis=(0, 1, 2, 3))
std = np.std(X_train, axis=(0, 1, 2, 3))

X_train = (X_train - mean) / (std + 1e-7)
X_valid = (X_valid - mean) / (std + 1e-7)
X_test = (X_test - mean) / (std + 1e-7)

y_train_cat = to_categorical(y_train_single, 10)
y_valid_cat = to_categorical(y_valid_single, 10)
y_test_cat = to_categorical(y_test_single, 10)

y_train = [y_train_cat, y_train_cat, y_train_cat, y_train_cat]
y_valid = [y_valid_cat, y_valid_cat, y_valid_cat, y_valid_cat]
y_test = [y_test_cat, y_test_cat, y_test_cat, y_test_cat]

data_generator = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    shear_range=0.1,
    zoom_range=0.1
)

data_generator.fit(X_train)
# Out:
# Train Images Shape:       (45000, 32, 32, 3)
# Train Labels Shape:       (45000, 1)
#
# Validation Images Shape:  (5000, 32, 32, 3)
# Validation Labels Shape:  (5000, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
def create_early_exit_cnn_model(input_shape, num_classes=10):
    weight_decay = 0.0001
    
    inputs = Input(shape=input_shape)
    x = inputs
    outputs = []
    
    x = Conv2D(filters=32, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv1_1')(x)
    x = BatchNormalization(name='bn1_1')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=32, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv1_2')(x)
    x = BatchNormalization(name='bn1_2')(x)
    x = Activation('relu')(x)
    pool1 = MaxPooling2D(pool_size=(2, 2), name='pool1')(x)
    x = Dropout(rate=0.2, name='drop1')(pool1)
    
    exit1 = Flatten(name='flatten1')(pool1)
    exit1 = Dense(num_classes, activation='softmax', name='output_exit_1')(exit1)
    outputs.append(exit1)
    
    x = Conv2D(filters=64, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv2_1')(x)   
    x = BatchNormalization(name='bn2_1')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=64, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv2_2')(x)
    x = BatchNormalization(name='bn2_2')(x)
    x = Activation('relu')(x)
    pool2 = MaxPooling2D(pool_size=(2, 2), name='pool2')(x)
    x = Dropout(rate=0.3, name='drop2')(pool2)
    
    exit2 = Flatten(name='flatten2')(pool2)
    exit2 = Dense(num_classes, activation='softmax', name='output_exit_2')(exit2)
    outputs.append(exit2)
    
    x = Conv2D(filters=128, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv3_1')(x) 
    x = BatchNormalization(name='bn3_1')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=128, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv3_2')(x)
    x = BatchNormalization(name='bn3_2')(x)
    x = Activation('relu')(x)
    pool3 = MaxPooling2D(pool_size=(2, 2), name='pool3')(x)
    x = Dropout(rate=0.4, name='drop3')(pool3)
    
    exit3 = Flatten(name='flatten3')(pool3)
    exit3 = Dense(num_classes, activation='softmax', name='output_exit_3')(exit3)
    outputs.append(exit3)
    
    x = Conv2D(filters=256, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv4_1')(x) 
    x = BatchNormalization(name='bn4_1')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=256, kernel_size=(3,3), padding='same', kernel_regularizer=l2(weight_decay), name='conv4_2')(x)
    x = BatchNormalization(name='bn4_2')(x)
    x = Activation('relu')(x)
    pool4 = MaxPooling2D(pool_size=(2, 2), name='pool4')(x)
    x = Dropout(rate=0.5, name='drop4')(pool4)

    x = Flatten(name='flatten4')(x)
    main_output = Dense(num_classes, activation='softmax', name='output_main')(x)
    outputs.append(main_output)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

model = create_early_exit_cnn_model(X_train.shape[1:])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_1 (Conv2D)    │ (None, 32, 32,    │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1_1               │ (None, 32, 32,    │        128 │ conv1_1[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ bn1_1[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_2 (Conv2D)    │ (None, 32, 32,    │      9,248 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1_2               │ (None, 32, 32,    │        128 │ conv1_2[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32,    │          0 │ bn1_2[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1               │ (None, 16, 16,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop1 (Dropout)     │ (None, 16, 16,    │          0 │ pool1[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_1 (Conv2D)    │ (None, 16, 16,    │     18,496 │ drop1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn2_1               │ (None, 16, 16,    │        256 │ conv2_1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 16,    │          0 │ bn2_1[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_2 (Conv2D)    │ (None, 16, 16,    │     36,928 │ activation_2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn2_2               │ (None, 16, 16,    │        256 │ conv2_2[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 16, 16,    │          0 │ bn2_2[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2               │ (None, 8, 8, 64)  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop2 (Dropout)     │ (None, 8, 8, 64)  │          0 │ pool2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_1 (Conv2D)    │ (None, 8, 8, 128) │     73,856 │ drop2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn3_1               │ (None, 8, 8, 128) │        512 │ conv3_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 8, 128) │          0 │ bn3_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_2 (Conv2D)    │ (None, 8, 8, 128) │    147,584 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn3_2               │ (None, 8, 8, 128) │        512 │ conv3_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 8, 8, 128) │          0 │ bn3_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3               │ (None, 4, 4, 128) │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop3 (Dropout)     │ (None, 4, 4, 128) │          0 │ pool3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_1 (Conv2D)    │ (None, 4, 4, 256) │    295,168 │ drop3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn4_1               │ (None, 4, 4, 256) │      1,024 │ conv4_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 4, 4, 256) │          0 │ bn4_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_2 (Conv2D)    │ (None, 4, 4, 256) │    590,080 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn4_2               │ (None, 4, 4, 256) │      1,024 │ conv4_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 4, 4, 256) │          0 │ bn4_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool4               │ (None, 2, 2, 256) │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop4 (Dropout)     │ (None, 2, 2, 256) │          0 │ pool4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten1 (Flatten)  │ (None, 8192)      │          0 │ pool1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten2 (Flatten)  │ (None, 4096)      │          0 │ pool2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten3 (Flatten)  │ (None, 2048)      │          0 │ pool3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten4 (Flatten)  │ (None, 1024)      │          0 │ drop4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_exit_1       │ (None, 10)        │     81,930 │ flatten1[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_exit_2       │ (None, 10)        │     40,970 │ flatten2[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_exit_3       │ (None, 10)        │     20,490 │ flatten3[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_main (Dense) │ (None, 10)        │     10,250 │ flatten4[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,329,736 (5.07 MB)
#  Trainable params: 1,327,816 (5.07 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
batch_size = 64
epochs = 300

optimizer = Adam(learning_rate=0.0005)

loss = ['categorical_crossentropy'] * 4
loss_weights = [0.2, 0.2, 0.2, 0.4]
metrics = {'output_exit_1': 'accuracy', 'output_exit_2': 'accuracy', 'output_exit_3': 'accuracy', 'output_main': 'accuracy'}

model.compile(optimizer=optimizer, loss=loss, loss_weights=loss_weights, metrics=metrics)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

try:
    model = load_model('cifar10_cnn_model_early_exit.h5')
    print("Modelo Early-Exit pré-treinado carregado com sucesso.")
except:
    print("Modelo Early-Exit pré-treinado não encontrado. Iniciando o treinamento...")
    
    def multi_output_generator(generator, y_data):
        for x_batch, y_batch in generator.flow(X_train, y_data[0], batch_size=batch_size):
            yield x_batch, y_data
            
    def multi_output_data_generator(X, Y_list, batch_size):
        gen = ImageDataGenerator(
            rotation_range=15,
            width_shift_range=0.1,
            height_shift_range=0.1,
            horizontal_flip=True,
            shear_range=0.1,
            zoom_range=0.1
        )
        gen.fit(X)
        
        print("Treinando sem Data Augmentation para simplificar o Multi-Output/Early-Exit.")
        history = model.fit(
            X_train, y_train, 
            batch_size=batch_size,
            epochs=epochs,
            validation_data=(X_valid, y_valid),
            callbacks=[reduce_lr, early_stopping], 
            verbose=2
        )
        return history
    
    multi_output_data_generator(X_train, y_train, batch_size)
    
    model.save('cifar10_cnn_model_early_exit.h5')
    print("Modelo Early-Exit treinado e salvo.")
# Out:
# Modelo Early-Exit pré-treinado não encontrado. Iniciando o treinamento...
# Treinando sem Data Augmentation para simplificar o Multi-Output/Early-Exit.
# Epoch 1/300
# 704/704 - 42s - 60ms/step - loss: 1.7093 - output_exit_1_accuracy: 0.4765 - output_exit_1_loss: 1.5280 - output_exit_2_accuracy: 0.4745 - output_exit_2_loss: 1.5029 - output_exit_3_accuracy: 0.4659 - output_exit_3_loss: 1.5027 - output_main_accuracy: 0.3786 - output_main_loss: 1.8036 - val_loss: 1.3976 - val_output_exit_1_accuracy: 0.5680 - val_output_exit_1_loss: 1.2155 - val_output_exit_2_accuracy: 0.5902 - val_output_exit_2_loss: 1.1566 - val_output_exit_3_accuracy: 0.5296 - val_output_exit_3_loss: 1.3210 - val_output_main_accuracy: 0.4762 - val_output_main_loss: 1.4460 - learning_rate: 5.0000e-04
# Epoch 2/300
# 704/704 - 38s - 54ms/step - loss: 1.1845 - output_exit_1_accuracy: 0.6181 - output_exit_1_loss: 1.1083 - output_exit_2_accuracy: 0.6366 - output_exit_2_loss: 1.0380 - output_exit_3_accuracy: 0.6368 - output_exit_3_loss: 1.0245 - output_main_accuracy: 0.5797 - output_main_loss: 1.1703 - val_loss: 1.1159 - val_output_exit_1_accuracy: 0.6384 - val_output_exit_1_loss: 1.0406 - val_output_exit_2_accuracy: 0.6506 - val_output_exit_2_loss: 1.0013 - val_output_exit_3_accuracy: 0.6472 - val_output_exit_3_loss: 1.0043 - val_output_main_accuracy: 0.6314 - val_output_main_loss: 1.0595 - learning_rate: 5.0000e-04
# Epoch 3/300
# 704/704 - 39s - 56ms/step - loss: 0.9918 - output_exit_1_accuracy: 0.6713 - output_exit_1_loss: 0.9522 - output_exit_2_accuracy: 0.6960 - output_exit_2_loss: 0.8704 - output_exit_3_accuracy: 0.7077 - output_exit_3_loss: 0.8336 - output_main_accuracy: 0.6664 - output_main_loss: 0.9454 - val_loss: 0.9129 - val_output_exit_1_accuracy: 0.6542 - val_output_exit_1_loss: 1.0146 - val_output_exit_2_accuracy: 0.7044 - val_output_exit_2_loss: 0.8273 - val_output_exit_3_accuracy: 0.7318 - val_output_exit_3_loss: 0.7520 - val_output_main_accuracy: 0.7240 - val_output_main_loss: 0.7752 - learning_rate: 5.0000e-04
# Epoch 4/300
# 704/704 - 38s - 55ms/step - loss: 0.8827 - output_exit_1_accuracy: 0.7032 - output_exit_1_loss: 0.8586 - output_exit_2_accuracy: 0.7304 - output_exit_2_loss: 0.7710 - output_exit_3_accuracy: 0.7479 - output_exit_3_loss: 0.7219 - output_main_accuracy: 0.7133 - output_main_loss: 0.8220 - val_loss: 0.9717 - val_output_exit_1_accuracy: 0.6624 - val_output_exit_1_loss: 0.9951 - val_output_exit_2_accuracy: 0.7124 - val_output_exit_2_loss: 0.8192 - val_output_exit_3_accuracy: 0.7134 - val_output_exit_3_loss: 0.8432 - val_output_main_accuracy: 0.6934 - val_output_main_loss: 0.8895 - learning_rate: 5.0000e-04
# Epoch 5/300
# 704/704 - 38s - 54ms/step - loss: 0.8147 - output_exit_1_accuracy: 0.7257 - output_exit_1_loss: 0.7952 - output_exit_2_accuracy: 0.7525 - output_exit_2_loss: 0.7105 - output_exit_3_accuracy: 0.7715 - output_exit_3_loss: 0.6527 - output_main_accuracy: 0.7381 - output_main_loss: 0.7491 - val_loss: 0.8543 - val_output_exit_1_accuracy: 0.6544 - val_output_exit_1_loss: 1.0359 - val_output_exit_2_accuracy: 0.7376 - val_output_exit_2_loss: 0.7688 - val_output_exit_3_accuracy: 0.7712 - val_output_exit_3_loss: 0.6775 - val_output_main_accuracy: 0.7658 - val_output_main_loss: 0.6887 - learning_rate: 5.0000e-04
# Epoch 6/300
# 704/704 - 37s - 53ms/step - loss: 0.7584 - output_exit_1_accuracy: 0.7447 - output_exit_1_loss: 0.7402 - output_exit_2_accuracy: 0.7728 - output_exit_2_loss: 0.6524 - output_exit_3_accuracy: 0.7932 - output_exit_3_loss: 0.5949 - output_main_accuracy: 0.7602 - output_main_loss: 0.6904 - val_loss: 0.8326 - val_output_exit_1_accuracy: 0.6554 - val_output_exit_1_loss: 1.0422 - val_output_exit_2_accuracy: 0.7456 - val_output_exit_2_loss: 0.7534 - val_output_exit_3_accuracy: 0.7678 - val_output_exit_3_loss: 0.6594 - val_output_main_accuracy: 0.7740 - val_output_main_loss: 0.6507 - learning_rate: 5.0000e-04
# Epoch 7/300
# 704/704 - 39s - 55ms/step - loss: 0.7135 - output_exit_1_accuracy: 0.7562 - output_exit_1_loss: 0.7013 - output_exit_2_accuracy: 0.7878 - output_exit_2_loss: 0.6109 - output_exit_3_accuracy: 0.8098 - output_exit_3_loss: 0.5506 - output_main_accuracy: 0.7787 - output_main_loss: 0.6385 - val_loss: 0.8800 - val_output_exit_1_accuracy: 0.6336 - val_output_exit_1_loss: 1.1661 - val_output_exit_2_accuracy: 0.7386 - val_output_exit_2_loss: 0.7918 - val_output_exit_3_accuracy: 0.7592 - val_output_exit_3_loss: 0.7042 - val_output_main_accuracy: 0.7690 - val_output_main_loss: 0.6588 - learning_rate: 5.0000e-04
# Epoch 8/300
# 704/704 - 41s - 58ms/step - loss: 0.6729 - output_exit_1_accuracy: 0.7750 - output_exit_1_loss: 0.6524 - output_exit_2_accuracy: 0.7997 - output_exit_2_loss: 0.5719 - output_exit_3_accuracy: 0.8224 - output_exit_3_loss: 0.5076 - output_main_accuracy: 0.7926 - output_main_loss: 0.5982 - val_loss: 0.7478 - val_output_exit_1_accuracy: 0.6528 - val_output_exit_1_loss: 1.0741 - val_output_exit_2_accuracy: 0.7842 - val_output_exit_2_loss: 0.6404 - val_output_exit_3_accuracy: 0.8214 - val_output_exit_3_loss: 0.5284 - val_output_main_accuracy: 0.8206 - val_output_main_loss: 0.5275 - learning_rate: 5.0000e-04
# Epoch 9/300
# 704/704 - 40s - 57ms/step - loss: 0.6476 - output_exit_1_accuracy: 0.7866 - output_exit_1_loss: 0.6208 - output_exit_2_accuracy: 0.8091 - output_exit_2_loss: 0.5426 - output_exit_3_accuracy: 0.8327 - output_exit_3_loss: 0.4802 - output_main_accuracy: 0.8016 - output_main_loss: 0.5728 - val_loss: 0.8035 - val_output_exit_1_accuracy: 0.6812 - val_output_exit_1_loss: 0.9945 - val_output_exit_2_accuracy: 0.7572 - val_output_exit_2_loss: 0.7152 - val_output_exit_3_accuracy: 0.7890 - val_output_exit_3_loss: 0.6240 - val_output_main_accuracy: 0.7844 - val_output_main_loss: 0.6146 - learning_rate: 5.0000e-04
# Epoch 10/300
# 704/704 - 39s - 56ms/step - loss: 0.6086 - output_exit_1_accuracy: 0.7981 - output_exit_1_loss: 0.5821 - output_exit_2_accuracy: 0.8229 - output_exit_2_loss: 0.5077 - output_exit_3_accuracy: 0.8467 - output_exit_3_loss: 0.4403 - output_main_accuracy: 0.8169 - output_main_loss: 0.5299 - val_loss: 0.7769 - val_output_exit_1_accuracy: 0.6664 - val_output_exit_1_loss: 1.0791 - val_output_exit_2_accuracy: 0.7744 - val_output_exit_2_loss: 0.6623 - val_output_exit_3_accuracy: 0.8130 - val_output_exit_3_loss: 0.5706 - val_output_main_accuracy: 0.8100 - val_output_main_loss: 0.5695 - learning_rate: 5.0000e-04
# Epoch 11/300
# 704/704 - 40s - 57ms/step - loss: 0.5900 - output_exit_1_accuracy: 0.8068 - output_exit_1_loss: 0.5577 - output_exit_2_accuracy: 0.8314 - output_exit_2_loss: 0.4813 - output_exit_3_accuracy: 0.8534 - output_exit_3_loss: 0.4227 - output_main_accuracy: 0.8225 - output_main_loss: 0.5109 - val_loss: 0.7760 - val_output_exit_1_accuracy: 0.6602 - val_output_exit_1_loss: 1.0891 - val_output_exit_2_accuracy: 0.7688 - val_output_exit_2_loss: 0.7093 - val_output_exit_3_accuracy: 0.8192 - val_output_exit_3_loss: 0.5541 - val_output_main_accuracy: 0.8236 - val_output_main_loss: 0.5346 - learning_rate: 5.0000e-04
# Epoch 12/300
# 704/704 - 40s - 57ms/step - loss: 0.5709 - output_exit_1_accuracy: 0.8146 - output_exit_1_loss: 0.5317 - output_exit_2_accuracy: 0.8379 - output_exit_2_loss: 0.4611 - output_exit_3_accuracy: 0.8604 - output_exit_3_loss: 0.3987 - output_main_accuracy: 0.8295 - output_main_loss: 0.4939 - val_loss: 0.7390 - val_output_exit_1_accuracy: 0.6698 - val_output_exit_1_loss: 1.0906 - val_output_exit_2_accuracy: 0.7906 - val_output_exit_2_loss: 0.6219 - val_output_exit_3_accuracy: 0.8274 - val_output_exit_3_loss: 0.5037 - val_output_main_accuracy: 0.8326 - val_output_main_loss: 0.4995 - learning_rate: 5.0000e-04
# Epoch 13/300
# 704/704 - 39s - 56ms/step - loss: 0.5494 - output_exit_1_accuracy: 0.8249 - output_exit_1_loss: 0.5028 - output_exit_2_accuracy: 0.8459 - output_exit_2_loss: 0.4389 - output_exit_3_accuracy: 0.8684 - output_exit_3_loss: 0.3746 - output_main_accuracy: 0.8362 - output_main_loss: 0.4727 - val_loss: 0.7550 - val_output_exit_1_accuracy: 0.6774 - val_output_exit_1_loss: 1.0731 - val_output_exit_2_accuracy: 0.7924 - val_output_exit_2_loss: 0.6118 - val_output_exit_3_accuracy: 0.8220 - val_output_exit_3_loss: 0.5384 - val_output_main_accuracy: 0.8228 - val_output_main_loss: 0.5371 - learning_rate: 5.0000e-04
# Epoch 14/300
# 704/704 - 41s - 58ms/step - loss: 0.5347 - output_exit_1_accuracy: 0.8337 - output_exit_1_loss: 0.4812 - output_exit_2_accuracy: 0.8517 - output_exit_2_loss: 0.4244 - output_exit_3_accuracy: 0.8716 - output_exit_3_loss: 0.3622 - output_main_accuracy: 0.8403 - output_main_loss: 0.4567 - val_loss: 0.7431 - val_output_exit_1_accuracy: 0.6544 - val_output_exit_1_loss: 1.1780 - val_output_exit_2_accuracy: 0.7988 - val_output_exit_2_loss: 0.6050 - val_output_exit_3_accuracy: 0.8382 - val_output_exit_3_loss: 0.4801 - val_output_main_accuracy: 0.8330 - val_output_main_loss: 0.4829 - learning_rate: 5.0000e-04
# Epoch 15/300
# 704/704 - 40s - 57ms/step - loss: 0.5160 - output_exit_1_accuracy: 0.8402 - output_exit_1_loss: 0.4579 - output_exit_2_accuracy: 0.8600 - output_exit_2_loss: 0.4030 - output_exit_3_accuracy: 0.8836 - output_exit_3_loss: 0.3368 - output_main_accuracy: 0.8465 - output_main_loss: 0.4389 - val_loss: 0.7740 - val_output_exit_1_accuracy: 0.6730 - val_output_exit_1_loss: 1.1157 - val_output_exit_2_accuracy: 0.7886 - val_output_exit_2_loss: 0.6566 - val_output_exit_3_accuracy: 0.8228 - val_output_exit_3_loss: 0.5276 - val_output_main_accuracy: 0.8230 - val_output_main_loss: 0.5324 - learning_rate: 5.0000e-04
# Epoch 16/300
# 704/704 - 40s - 56ms/step - loss: 0.5003 - output_exit_1_accuracy: 0.8466 - output_exit_1_loss: 0.4390 - output_exit_2_accuracy: 0.8644 - output_exit_2_loss: 0.3857 - output_exit_3_accuracy: 0.8867 - output_exit_3_loss: 0.3216 - output_main_accuracy: 0.8534 - output_main_loss: 0.4216 - val_loss: 0.7539 - val_output_exit_1_accuracy: 0.6644 - val_output_exit_1_loss: 1.1581 - val_output_exit_2_accuracy: 0.7872 - val_output_exit_2_loss: 0.6307 - val_output_exit_3_accuracy: 0.8366 - val_output_exit_3_loss: 0.4884 - val_output_main_accuracy: 0.8348 - val_output_main_loss: 0.4867 - learning_rate: 5.0000e-04
# Epoch 17/300
# 704/704 - 39s - 55ms/step - loss: 0.4919 - output_exit_1_accuracy: 0.8529 - output_exit_1_loss: 0.4202 - output_exit_2_accuracy: 0.8684 - output_exit_2_loss: 0.3753 - output_exit_3_accuracy: 0.8887 - output_exit_3_loss: 0.3136 - output_main_accuracy: 0.8560 - output_main_loss: 0.4172 - val_loss: 0.7682 - val_output_exit_1_accuracy: 0.6744 - val_output_exit_1_loss: 1.1280 - val_output_exit_2_accuracy: 0.7936 - val_output_exit_2_loss: 0.6368 - val_output_exit_3_accuracy: 0.8244 - val_output_exit_3_loss: 0.5279 - val_output_main_accuracy: 0.8274 - val_output_main_loss: 0.5169 - learning_rate: 5.0000e-04
# Epoch 18/300
# 704/704 - 39s - 55ms/step - loss: 0.4787 - output_exit_1_accuracy: 0.8626 - output_exit_1_loss: 0.3994 - output_exit_2_accuracy: 0.8719 - output_exit_2_loss: 0.3648 - output_exit_3_accuracy: 0.8931 - output_exit_3_loss: 0.2999 - output_main_accuracy: 0.8593 - output_main_loss: 0.3992 - val_loss: 0.7601 - val_output_exit_1_accuracy: 0.6660 - val_output_exit_1_loss: 1.1785 - val_output_exit_2_accuracy: 0.7990 - val_output_exit_2_loss: 0.6210 - val_output_exit_3_accuracy: 0.8334 - val_output_exit_3_loss: 0.5197 - val_output_main_accuracy: 0.8426 - val_output_main_loss: 0.4806 - learning_rate: 5.0000e-04
# Epoch 19/300
# 704/704 - 39s - 56ms/step - loss: 0.4628 - output_exit_1_accuracy: 0.8698 - output_exit_1_loss: 0.3802 - output_exit_2_accuracy: 0.8808 - output_exit_2_loss: 0.3417 - output_exit_3_accuracy: 0.9009 - output_exit_3_loss: 0.2831 - output_main_accuracy: 0.8652 - output_main_loss: 0.3868 - val_loss: 0.7769 - val_output_exit_1_accuracy: 0.6754 - val_output_exit_1_loss: 1.1596 - val_output_exit_2_accuracy: 0.7854 - val_output_exit_2_loss: 0.6582 - val_output_exit_3_accuracy: 0.8400 - val_output_exit_3_loss: 0.5094 - val_output_main_accuracy: 0.8306 - val_output_main_loss: 0.5089 - learning_rate: 5.0000e-04
# Epoch 20/300
# 704/704 - 39s - 56ms/step - loss: 0.4570 - output_exit_1_accuracy: 0.8750 - output_exit_1_loss: 0.3648 - output_exit_2_accuracy: 0.8824 - output_exit_2_loss: 0.3350 - output_exit_3_accuracy: 0.9012 - output_exit_3_loss: 0.2768 - output_main_accuracy: 0.8682 - output_main_loss: 0.3819 - val_loss: 0.9573 - val_output_exit_1_accuracy: 0.6504 - val_output_exit_1_loss: 1.3231 - val_output_exit_2_accuracy: 0.7444 - val_output_exit_2_loss: 0.8408 - val_output_exit_3_accuracy: 0.7998 - val_output_exit_3_loss: 0.6784 - val_output_main_accuracy: 0.7796 - val_output_main_loss: 0.7235 - learning_rate: 5.0000e-04
# Epoch 21/300
# 704/704 - 39s - 56ms/step - loss: 0.4437 - output_exit_1_accuracy: 0.8794 - output_exit_1_loss: 0.3524 - output_exit_2_accuracy: 0.8866 - output_exit_2_loss: 0.3219 - output_exit_3_accuracy: 0.9059 - output_exit_3_loss: 0.2630 - output_main_accuracy: 0.8727 - output_main_loss: 0.3665 - val_loss: 0.7839 - val_output_exit_1_accuracy: 0.6720 - val_output_exit_1_loss: 1.2150 - val_output_exit_2_accuracy: 0.7916 - val_output_exit_2_loss: 0.6602 - val_output_exit_3_accuracy: 0.8364 - val_output_exit_3_loss: 0.5306 - val_output_main_accuracy: 0.8370 - val_output_main_loss: 0.4880 - learning_rate: 5.0000e-04
# Epoch 22/300
# 704/704 - 40s - 57ms/step - loss: 0.4373 - output_exit_1_accuracy: 0.8856 - output_exit_1_loss: 0.3364 - output_exit_2_accuracy: 0.8886 - output_exit_2_loss: 0.3153 - output_exit_3_accuracy: 0.9108 - output_exit_3_loss: 0.2549 - output_main_accuracy: 0.8748 - output_main_loss: 0.3606 - val_loss: 0.8158 - val_output_exit_1_accuracy: 0.6516 - val_output_exit_1_loss: 1.3288 - val_output_exit_2_accuracy: 0.7902 - val_output_exit_2_loss: 0.6372 - val_output_exit_3_accuracy: 0.8352 - val_output_exit_3_loss: 0.5217 - val_output_main_accuracy: 0.8308 - val_output_main_loss: 0.5264 - learning_rate: 5.0000e-04
# Epoch 23/300
# 704/704 - 39s - 56ms/step - loss: 0.3717 - output_exit_1_accuracy: 0.9197 - output_exit_1_loss: 0.2634 - output_exit_2_accuracy: 0.9109 - output_exit_2_loss: 0.2606 - output_exit_3_accuracy: 0.9318 - output_exit_3_loss: 0.1992 - output_main_accuracy: 0.8969 - output_main_loss: 0.2926 - val_loss: 0.7357 - val_output_exit_1_accuracy: 0.6712 - val_output_exit_1_loss: 1.2132 - val_output_exit_2_accuracy: 0.8158 - val_output_exit_2_loss: 0.5875 - val_output_exit_3_accuracy: 0.8532 - val_output_exit_3_loss: 0.4673 - val_output_main_accuracy: 0.8590 - val_output_main_loss: 0.4409 - learning_rate: 2.5000e-04
# Epoch 24/300
# 704/704 - 40s - 57ms/step - loss: 0.3548 - output_exit_1_accuracy: 0.9284 - output_exit_1_loss: 0.2458 - output_exit_2_accuracy: 0.9141 - output_exit_2_loss: 0.2498 - output_exit_3_accuracy: 0.9346 - output_exit_3_loss: 0.1876 - output_main_accuracy: 0.9021 - output_main_loss: 0.2785 - val_loss: 0.7518 - val_output_exit_1_accuracy: 0.6728 - val_output_exit_1_loss: 1.2450 - val_output_exit_2_accuracy: 0.8138 - val_output_exit_2_loss: 0.5894 - val_output_exit_3_accuracy: 0.8528 - val_output_exit_3_loss: 0.4738 - val_output_main_accuracy: 0.8558 - val_output_main_loss: 0.4629 - learning_rate: 2.5000e-04
# Epoch 25/300
# 704/704 - 40s - 57ms/step - loss: 0.3409 - output_exit_1_accuracy: 0.9287 - output_exit_1_loss: 0.2405 - output_exit_2_accuracy: 0.9170 - output_exit_2_loss: 0.2445 - output_exit_3_accuracy: 0.9402 - output_exit_3_loss: 0.1735 - output_main_accuracy: 0.9065 - output_main_loss: 0.2623 - val_loss: 0.7398 - val_output_exit_1_accuracy: 0.6744 - val_output_exit_1_loss: 1.2708 - val_output_exit_2_accuracy: 0.8042 - val_output_exit_2_loss: 0.6265 - val_output_exit_3_accuracy: 0.8576 - val_output_exit_3_loss: 0.4647 - val_output_main_accuracy: 0.8692 - val_output_main_loss: 0.4197 - learning_rate: 2.5000e-04
# Epoch 26/300
# 704/704 - 39s - 56ms/step - loss: 0.3297 - output_exit_1_accuracy: 0.9334 - output_exit_1_loss: 0.2312 - output_exit_2_accuracy: 0.9200 - output_exit_2_loss: 0.2366 - output_exit_3_accuracy: 0.9432 - output_exit_3_loss: 0.1669 - output_main_accuracy: 0.9092 - output_main_loss: 0.2516 - val_loss: 0.7448 - val_output_exit_1_accuracy: 0.6646 - val_output_exit_1_loss: 1.2948 - val_output_exit_2_accuracy: 0.8112 - val_output_exit_2_loss: 0.6028 - val_output_exit_3_accuracy: 0.8606 - val_output_exit_3_loss: 0.4603 - val_output_main_accuracy: 0.8658 - val_output_main_loss: 0.4315 - learning_rate: 2.5000e-04
# Epoch 27/300
# 704/704 - 39s - 55ms/step - loss: 0.3226 - output_exit_1_accuracy: 0.9352 - output_exit_1_loss: 0.2242 - output_exit_2_accuracy: 0.9205 - output_exit_2_loss: 0.2323 - output_exit_3_accuracy: 0.9435 - output_exit_3_loss: 0.1605 - output_main_accuracy: 0.9111 - output_main_loss: 0.2476 - val_loss: 0.7246 - val_output_exit_1_accuracy: 0.6728 - val_output_exit_1_loss: 1.2969 - val_output_exit_2_accuracy: 0.8160 - val_output_exit_2_loss: 0.5996 - val_output_exit_3_accuracy: 0.8678 - val_output_exit_3_loss: 0.4409 - val_output_main_accuracy: 0.8732 - val_output_main_loss: 0.4012 - learning_rate: 2.5000e-04
# Epoch 28/300
# 704/704 - 39s - 55ms/step - loss: 0.3173 - output_exit_1_accuracy: 0.9394 - output_exit_1_loss: 0.2163 - output_exit_2_accuracy: 0.9213 - output_exit_2_loss: 0.2286 - output_exit_3_accuracy: 0.9450 - output_exit_3_loss: 0.1572 - output_main_accuracy: 0.9123 - output_main_loss: 0.2438 - val_loss: 0.7489 - val_output_exit_1_accuracy: 0.6676 - val_output_exit_1_loss: 1.3771 - val_output_exit_2_accuracy: 0.8118 - val_output_exit_2_loss: 0.6065 - val_output_exit_3_accuracy: 0.8666 - val_output_exit_3_loss: 0.4507 - val_output_main_accuracy: 0.8704 - val_output_main_loss: 0.4157 - learning_rate: 2.5000e-04
# Epoch 29/300
# 704/704 - 40s - 56ms/step - loss: 0.3100 - output_exit_1_accuracy: 0.9387 - output_exit_1_loss: 0.2121 - output_exit_2_accuracy: 0.9236 - output_exit_2_loss: 0.2245 - output_exit_3_accuracy: 0.9479 - output_exit_3_loss: 0.1511 - output_main_accuracy: 0.9164 - output_main_loss: 0.2361 - val_loss: 0.7434 - val_output_exit_1_accuracy: 0.6696 - val_output_exit_1_loss: 1.3203 - val_output_exit_2_accuracy: 0.8112 - val_output_exit_2_loss: 0.6242 - val_output_exit_3_accuracy: 0.8654 - val_output_exit_3_loss: 0.4607 - val_output_main_accuracy: 0.8684 - val_output_main_loss: 0.4223 - learning_rate: 2.5000e-04
# Epoch 30/300
# 704/704 - 40s - 57ms/step - loss: 0.3041 - output_exit_1_accuracy: 0.9430 - output_exit_1_loss: 0.2031 - output_exit_2_accuracy: 0.9253 - output_exit_2_loss: 0.2167 - output_exit_3_accuracy: 0.9501 - output_exit_3_loss: 0.1458 - output_main_accuracy: 0.9161 - output_main_loss: 0.2332 - val_loss: 0.7998 - val_output_exit_1_accuracy: 0.6598 - val_output_exit_1_loss: 1.4224 - val_output_exit_2_accuracy: 0.8072 - val_output_exit_2_loss: 0.6335 - val_output_exit_3_accuracy: 0.8472 - val_output_exit_3_loss: 0.5091 - val_output_main_accuracy: 0.8520 - val_output_main_loss: 0.4877 - learning_rate: 2.5000e-04
# Epoch 31/300
# 704/704 - 40s - 57ms/step - loss: 0.2992 - output_exit_1_accuracy: 0.9453 - output_exit_1_loss: 0.1963 - output_exit_2_accuracy: 0.9277 - output_exit_2_loss: 0.2124 - output_exit_3_accuracy: 0.9508 - output_exit_3_loss: 0.1426 - output_main_accuracy: 0.9171 - output_main_loss: 0.2303 - val_loss: 0.7608 - val_output_exit_1_accuracy: 0.6758 - val_output_exit_1_loss: 1.3652 - val_output_exit_2_accuracy: 0.8106 - val_output_exit_2_loss: 0.6311 - val_output_exit_3_accuracy: 0.8666 - val_output_exit_3_loss: 0.4665 - val_output_main_accuracy: 0.8684 - val_output_main_loss: 0.4352 - learning_rate: 2.5000e-04
# Epoch 32/300
# 704/704 - 40s - 57ms/step - loss: 0.2922 - output_exit_1_accuracy: 0.9454 - output_exit_1_loss: 0.1947 - output_exit_2_accuracy: 0.9294 - output_exit_2_loss: 0.2094 - output_exit_3_accuracy: 0.9527 - output_exit_3_loss: 0.1368 - output_main_accuracy: 0.9212 - output_main_loss: 0.2210 - val_loss: 0.7616 - val_output_exit_1_accuracy: 0.6658 - val_output_exit_1_loss: 1.4068 - val_output_exit_2_accuracy: 0.8086 - val_output_exit_2_loss: 0.6519 - val_output_exit_3_accuracy: 0.8610 - val_output_exit_3_loss: 0.4601 - val_output_main_accuracy: 0.8700 - val_output_main_loss: 0.4090 - learning_rate: 2.5000e-04
# Epoch 33/300
# 704/704 - 40s - 57ms/step - loss: 0.2893 - output_exit_1_accuracy: 0.9476 - output_exit_1_loss: 0.1872 - output_exit_2_accuracy: 0.9287 - output_exit_2_loss: 0.2068 - output_exit_3_accuracy: 0.9529 - output_exit_3_loss: 0.1332 - output_main_accuracy: 0.9206 - output_main_loss: 0.2209 - val_loss: 0.7671 - val_output_exit_1_accuracy: 0.6650 - val_output_exit_1_loss: 1.4009 - val_output_exit_2_accuracy: 0.8158 - val_output_exit_2_loss: 0.6413 - val_output_exit_3_accuracy: 0.8624 - val_output_exit_3_loss: 0.4743 - val_output_main_accuracy: 0.8628 - val_output_main_loss: 0.4325 - learning_rate: 2.5000e-04
# Epoch 34/300
# 704/704 - 39s - 56ms/step - loss: 0.2848 - output_exit_1_accuracy: 0.9508 - output_exit_1_loss: 0.1803 - output_exit_2_accuracy: 0.9314 - output_exit_2_loss: 0.2014 - output_exit_3_accuracy: 0.9532 - output_exit_3_loss: 0.1328 - output_main_accuracy: 0.9235 - output_main_loss: 0.2159 - val_loss: 0.7728 - val_output_exit_1_accuracy: 0.6668 - val_output_exit_1_loss: 1.4322 - val_output_exit_2_accuracy: 0.8162 - val_output_exit_2_loss: 0.6186 - val_output_exit_3_accuracy: 0.8618 - val_output_exit_3_loss: 0.4774 - val_output_main_accuracy: 0.8638 - val_output_main_loss: 0.4348 - learning_rate: 2.5000e-04
# Epoch 35/300
# 704/704 - 39s - 55ms/step - loss: 0.2816 - output_exit_1_accuracy: 0.9540 - output_exit_1_loss: 0.1732 - output_exit_2_accuracy: 0.9326 - output_exit_2_loss: 0.1984 - output_exit_3_accuracy: 0.9548 - output_exit_3_loss: 0.1289 - output_main_accuracy: 0.9233 - output_main_loss: 0.2165 - val_loss: 0.7819 - val_output_exit_1_accuracy: 0.6676 - val_output_exit_1_loss: 1.4410 - val_output_exit_2_accuracy: 0.8100 - val_output_exit_2_loss: 0.6333 - val_output_exit_3_accuracy: 0.8606 - val_output_exit_3_loss: 0.4853 - val_output_main_accuracy: 0.8668 - val_output_main_loss: 0.4392 - learning_rate: 2.5000e-04
# Epoch 36/300
# 704/704 - 39s - 55ms/step - loss: 0.2791 - output_exit_1_accuracy: 0.9530 - output_exit_1_loss: 0.1706 - output_exit_2_accuracy: 0.9322 - output_exit_2_loss: 0.1974 - output_exit_3_accuracy: 0.9557 - output_exit_3_loss: 0.1280 - output_main_accuracy: 0.9236 - output_main_loss: 0.2124 - val_loss: 0.7756 - val_output_exit_1_accuracy: 0.6600 - val_output_exit_1_loss: 1.5050 - val_output_exit_2_accuracy: 0.8150 - val_output_exit_2_loss: 0.6358 - val_output_exit_3_accuracy: 0.8662 - val_output_exit_3_loss: 0.4500 - val_output_main_accuracy: 0.8754 - val_output_main_loss: 0.4087 - learning_rate: 2.5000e-04
# Epoch 37/300
# 704/704 - 39s - 55ms/step - loss: 0.2747 - output_exit_1_accuracy: 0.9565 - output_exit_1_loss: 0.1645 - output_exit_2_accuracy: 0.9340 - output_exit_2_loss: 0.1916 - output_exit_3_accuracy: 0.9574 - output_exit_3_loss: 0.1238 - output_main_accuracy: 0.9244 - output_main_loss: 0.2117 - val_loss: 0.7931 - val_output_exit_1_accuracy: 0.6584 - val_output_exit_1_loss: 1.5076 - val_output_exit_2_accuracy: 0.8086 - val_output_exit_2_loss: 0.6676 - val_output_exit_3_accuracy: 0.8568 - val_output_exit_3_loss: 0.4798 - val_output_main_accuracy: 0.8722 - val_output_main_loss: 0.4280 - learning_rate: 2.5000e-04
# Epoch 38/300
# 704/704 - 39s - 55ms/step - loss: 0.2443 - output_exit_1_accuracy: 0.9698 - output_exit_1_loss: 0.1360 - output_exit_2_accuracy: 0.9440 - output_exit_2_loss: 0.1684 - output_exit_3_accuracy: 0.9660 - output_exit_3_loss: 0.0998 - output_main_accuracy: 0.9378 - output_main_loss: 0.1733 - val_loss: 0.7703 - val_output_exit_1_accuracy: 0.6654 - val_output_exit_1_loss: 1.4765 - val_output_exit_2_accuracy: 0.8172 - val_output_exit_2_loss: 0.6245 - val_output_exit_3_accuracy: 0.8696 - val_output_exit_3_loss: 0.4510 - val_output_main_accuracy: 0.8760 - val_output_main_loss: 0.4190 - learning_rate: 1.2500e-04
# Epoch 39/300
# 704/704 - 39s - 55ms/step - loss: 0.2351 - output_exit_1_accuracy: 0.9730 - output_exit_1_loss: 0.1315 - output_exit_2_accuracy: 0.9462 - output_exit_2_loss: 0.1650 - output_exit_3_accuracy: 0.9698 - output_exit_3_loss: 0.0934 - output_main_accuracy: 0.9426 - output_main_loss: 0.1615 - val_loss: 0.7681 - val_output_exit_1_accuracy: 0.6698 - val_output_exit_1_loss: 1.4886 - val_output_exit_2_accuracy: 0.8156 - val_output_exit_2_loss: 0.6327 - val_output_exit_3_accuracy: 0.8678 - val_output_exit_3_loss: 0.4469 - val_output_main_accuracy: 0.8774 - val_output_main_loss: 0.4156 - learning_rate: 1.2500e-04
# Epoch 40/300
# 704/704 - 39s - 56ms/step - loss: 0.2289 - output_exit_1_accuracy: 0.9741 - output_exit_1_loss: 0.1270 - output_exit_2_accuracy: 0.9478 - output_exit_2_loss: 0.1587 - output_exit_3_accuracy: 0.9686 - output_exit_3_loss: 0.0917 - output_main_accuracy: 0.9447 - output_main_loss: 0.1549 - val_loss: 0.7694 - val_output_exit_1_accuracy: 0.6708 - val_output_exit_1_loss: 1.4961 - val_output_exit_2_accuracy: 0.8156 - val_output_exit_2_loss: 0.6220 - val_output_exit_3_accuracy: 0.8644 - val_output_exit_3_loss: 0.4483 - val_output_main_accuracy: 0.8780 - val_output_main_loss: 0.4200 - learning_rate: 1.2500e-04
# Epoch 41/300
# 704/704 - 40s - 57ms/step - loss: 0.2244 - output_exit_1_accuracy: 0.9742 - output_exit_1_loss: 0.1258 - output_exit_2_accuracy: 0.9478 - output_exit_2_loss: 0.1577 - output_exit_3_accuracy: 0.9711 - output_exit_3_loss: 0.0885 - output_main_accuracy: 0.9462 - output_main_loss: 0.1494 - val_loss: 0.7914 - val_output_exit_1_accuracy: 0.6656 - val_output_exit_1_loss: 1.5148 - val_output_exit_2_accuracy: 0.8120 - val_output_exit_2_loss: 0.6478 - val_output_exit_3_accuracy: 0.8690 - val_output_exit_3_loss: 0.4690 - val_output_main_accuracy: 0.8748 - val_output_main_loss: 0.4449 - learning_rate: 1.2500e-04
# Epoch 42/300
# 704/704 - 40s - 57ms/step - loss: 0.2250 - output_exit_1_accuracy: 0.9745 - output_exit_1_loss: 0.1237 - output_exit_2_accuracy: 0.9471 - output_exit_2_loss: 0.1578 - output_exit_3_accuracy: 0.9702 - output_exit_3_loss: 0.0888 - output_main_accuracy: 0.9459 - output_main_loss: 0.1544 - val_loss: 0.7713 - val_output_exit_1_accuracy: 0.6658 - val_output_exit_1_loss: 1.5280 - val_output_exit_2_accuracy: 0.8152 - val_output_exit_2_loss: 0.6266 - val_output_exit_3_accuracy: 0.8712 - val_output_exit_3_loss: 0.4439 - val_output_main_accuracy: 0.8800 - val_output_main_loss: 0.4169 - learning_rate: 1.2500e-04
# Epoch 43/300
# 704/704 - 40s - 56ms/step - loss: 0.2200 - output_exit_1_accuracy: 0.9772 - output_exit_1_loss: 0.1195 - output_exit_2_accuracy: 0.9493 - output_exit_2_loss: 0.1548 - output_exit_3_accuracy: 0.9714 - output_exit_3_loss: 0.0861 - output_main_accuracy: 0.9466 - output_main_loss: 0.1491 - val_loss: 0.7843 - val_output_exit_1_accuracy: 0.6652 - val_output_exit_1_loss: 1.5407 - val_output_exit_2_accuracy: 0.8192 - val_output_exit_2_loss: 0.6333 - val_output_exit_3_accuracy: 0.8706 - val_output_exit_3_loss: 0.4579 - val_output_main_accuracy: 0.8736 - val_output_main_loss: 0.4327 - learning_rate: 1.2500e-04
# Epoch 44/300
# 704/704 - 40s - 57ms/step - loss: 0.2149 - output_exit_1_accuracy: 0.9762 - output_exit_1_loss: 0.1181 - output_exit_2_accuracy: 0.9487 - output_exit_2_loss: 0.1518 - output_exit_3_accuracy: 0.9717 - output_exit_3_loss: 0.0833 - output_main_accuracy: 0.9494 - output_main_loss: 0.1421 - val_loss: 0.7792 - val_output_exit_1_accuracy: 0.6668 - val_output_exit_1_loss: 1.5527 - val_output_exit_2_accuracy: 0.8168 - val_output_exit_2_loss: 0.6287 - val_output_exit_3_accuracy: 0.8702 - val_output_exit_3_loss: 0.4565 - val_output_main_accuracy: 0.8798 - val_output_main_loss: 0.4202 - learning_rate: 1.2500e-04
# Epoch 45/300
# 704/704 - 40s - 57ms/step - loss: 0.2131 - output_exit_1_accuracy: 0.9777 - output_exit_1_loss: 0.1162 - output_exit_2_accuracy: 0.9494 - output_exit_2_loss: 0.1520 - output_exit_3_accuracy: 0.9723 - output_exit_3_loss: 0.0842 - output_main_accuracy: 0.9489 - output_main_loss: 0.1407 - val_loss: 0.7901 - val_output_exit_1_accuracy: 0.6666 - val_output_exit_1_loss: 1.5590 - val_output_exit_2_accuracy: 0.8204 - val_output_exit_2_loss: 0.6391 - val_output_exit_3_accuracy: 0.8700 - val_output_exit_3_loss: 0.4736 - val_output_main_accuracy: 0.8774 - val_output_main_loss: 0.4365 - learning_rate: 1.2500e-04
# Epoch 46/300
# 704/704 - 39s - 56ms/step - loss: 0.2084 - output_exit_1_accuracy: 0.9782 - output_exit_1_loss: 0.1130 - output_exit_2_accuracy: 0.9517 - output_exit_2_loss: 0.1470 - output_exit_3_accuracy: 0.9742 - output_exit_3_loss: 0.0789 - output_main_accuracy: 0.9516 - output_main_loss: 0.1370 - val_loss: 0.8105 - val_output_exit_1_accuracy: 0.6650 - val_output_exit_1_loss: 1.5867 - val_output_exit_2_accuracy: 0.8088 - val_output_exit_2_loss: 0.6546 - val_output_exit_3_accuracy: 0.8640 - val_output_exit_3_loss: 0.4780 - val_output_main_accuracy: 0.8696 - val_output_main_loss: 0.4622 - learning_rate: 1.2500e-04
# Epoch 47/300
# 704/704 - 39s - 55ms/step - loss: 0.2085 - output_exit_1_accuracy: 0.9791 - output_exit_1_loss: 0.1115 - output_exit_2_accuracy: 0.9525 - output_exit_2_loss: 0.1476 - output_exit_3_accuracy: 0.9749 - output_exit_3_loss: 0.0773 - output_main_accuracy: 0.9497 - output_main_loss: 0.1401 - val_loss: 0.7914 - val_output_exit_1_accuracy: 0.6614 - val_output_exit_1_loss: 1.5875 - val_output_exit_2_accuracy: 0.8160 - val_output_exit_2_loss: 0.6450 - val_output_exit_3_accuracy: 0.8684 - val_output_exit_3_loss: 0.4640 - val_output_main_accuracy: 0.8800 - val_output_main_loss: 0.4286 - learning_rate: 1.2500e-04
# Epoch 48/300
# 704/704 - 39s - 56ms/step - loss: 0.1954 - output_exit_1_accuracy: 0.9847 - output_exit_1_loss: 0.0978 - output_exit_2_accuracy: 0.9548 - output_exit_2_loss: 0.1385 - output_exit_3_accuracy: 0.9766 - output_exit_3_loss: 0.0711 - output_main_accuracy: 0.9554 - output_main_loss: 0.1237 - val_loss: 0.7776 - val_output_exit_1_accuracy: 0.6630 - val_output_exit_1_loss: 1.5799 - val_output_exit_2_accuracy: 0.8246 - val_output_exit_2_loss: 0.6148 - val_output_exit_3_accuracy: 0.8740 - val_output_exit_3_loss: 0.4489 - val_output_main_accuracy: 0.8826 - val_output_main_loss: 0.4168 - learning_rate: 6.2500e-05
# Epoch 49/300
# 704/704 - 39s - 55ms/step - loss: 0.1900 - output_exit_1_accuracy: 0.9859 - output_exit_1_loss: 0.0962 - output_exit_2_accuracy: 0.9571 - output_exit_2_loss: 0.1344 - output_exit_3_accuracy: 0.9788 - output_exit_3_loss: 0.0671 - output_main_accuracy: 0.9585 - output_main_loss: 0.1171 - val_loss: 0.7898 - val_output_exit_1_accuracy: 0.6684 - val_output_exit_1_loss: 1.5897 - val_output_exit_2_accuracy: 0.8202 - val_output_exit_2_loss: 0.6393 - val_output_exit_3_accuracy: 0.8718 - val_output_exit_3_loss: 0.4552 - val_output_main_accuracy: 0.8804 - val_output_main_loss: 0.4308 - learning_rate: 6.2500e-05
# Epoch 50/300
# 704/704 - 39s - 55ms/step - loss: 0.1868 - output_exit_1_accuracy: 0.9861 - output_exit_1_loss: 0.0947 - output_exit_2_accuracy: 0.9571 - output_exit_2_loss: 0.1339 - output_exit_3_accuracy: 0.9802 - output_exit_3_loss: 0.0642 - output_main_accuracy: 0.9597 - output_main_loss: 0.1135 - val_loss: 0.7917 - val_output_exit_1_accuracy: 0.6678 - val_output_exit_1_loss: 1.5975 - val_output_exit_2_accuracy: 0.8190 - val_output_exit_2_loss: 0.6409 - val_output_exit_3_accuracy: 0.8738 - val_output_exit_3_loss: 0.4562 - val_output_main_accuracy: 0.8802 - val_output_main_loss: 0.4321 - learning_rate: 6.2500e-05
# Epoch 51/300
# 704/704 - 39s - 55ms/step - loss: 0.1833 - output_exit_1_accuracy: 0.9864 - output_exit_1_loss: 0.0939 - output_exit_2_accuracy: 0.9589 - output_exit_2_loss: 0.1312 - output_exit_3_accuracy: 0.9814 - output_exit_3_loss: 0.0617 - output_main_accuracy: 0.9614 - output_main_loss: 0.1086 - val_loss: 0.7887 - val_output_exit_1_accuracy: 0.6686 - val_output_exit_1_loss: 1.6014 - val_output_exit_2_accuracy: 0.8192 - val_output_exit_2_loss: 0.6408 - val_output_exit_3_accuracy: 0.8720 - val_output_exit_3_loss: 0.4603 - val_output_main_accuracy: 0.8822 - val_output_main_loss: 0.4227 - learning_rate: 6.2500e-05
# Epoch 52/300
# 704/704 - 39s - 56ms/step - loss: 0.1846 - output_exit_1_accuracy: 0.9864 - output_exit_1_loss: 0.0934 - output_exit_2_accuracy: 0.9584 - output_exit_2_loss: 0.1314 - output_exit_3_accuracy: 0.9792 - output_exit_3_loss: 0.0648 - output_main_accuracy: 0.9596 - output_main_loss: 0.1122 - val_loss: 0.7910 - val_output_exit_1_accuracy: 0.6682 - val_output_exit_1_loss: 1.6146 - val_output_exit_2_accuracy: 0.8206 - val_output_exit_2_loss: 0.6385 - val_output_exit_3_accuracy: 0.8742 - val_output_exit_3_loss: 0.4581 - val_output_main_accuracy: 0.8838 - val_output_main_loss: 0.4249 - learning_rate: 6.2500e-05
# Epoch 53/300
# 704/704 - 40s - 57ms/step - loss: 0.1811 - output_exit_1_accuracy: 0.9872 - output_exit_1_loss: 0.0912 - output_exit_2_accuracy: 0.9594 - output_exit_2_loss: 0.1297 - output_exit_3_accuracy: 0.9811 - output_exit_3_loss: 0.0620 - output_main_accuracy: 0.9612 - output_main_loss: 0.1086 - val_loss: 0.7943 - val_output_exit_1_accuracy: 0.6704 - val_output_exit_1_loss: 1.6115 - val_output_exit_2_accuracy: 0.8186 - val_output_exit_2_loss: 0.6373 - val_output_exit_3_accuracy: 0.8682 - val_output_exit_3_loss: 0.4615 - val_output_main_accuracy: 0.8800 - val_output_main_loss: 0.4343 - learning_rate: 6.2500e-05
# Epoch 54/300
# 704/704 - 40s - 56ms/step - loss: 0.1796 - output_exit_1_accuracy: 0.9869 - output_exit_1_loss: 0.0907 - output_exit_2_accuracy: 0.9588 - output_exit_2_loss: 0.1302 - output_exit_3_accuracy: 0.9811 - output_exit_3_loss: 0.0625 - output_main_accuracy: 0.9630 - output_main_loss: 0.1058 - val_loss: 0.7908 - val_output_exit_1_accuracy: 0.6628 - val_output_exit_1_loss: 1.6151 - val_output_exit_2_accuracy: 0.8194 - val_output_exit_2_loss: 0.6317 - val_output_exit_3_accuracy: 0.8718 - val_output_exit_3_loss: 0.4588 - val_output_main_accuracy: 0.8822 - val_output_main_loss: 0.4264 - learning_rate: 6.2500e-05
# Epoch 55/300
# 704/704 - 40s - 57ms/step - loss: 0.1760 - output_exit_1_accuracy: 0.9883 - output_exit_1_loss: 0.0890 - output_exit_2_accuracy: 0.9591 - output_exit_2_loss: 0.1285 - output_exit_3_accuracy: 0.9825 - output_exit_3_loss: 0.0596 - output_main_accuracy: 0.9635 - output_main_loss: 0.1013 - val_loss: 0.8019 - val_output_exit_1_accuracy: 0.6648 - val_output_exit_1_loss: 1.6336 - val_output_exit_2_accuracy: 0.8176 - val_output_exit_2_loss: 0.6535 - val_output_exit_3_accuracy: 0.8684 - val_output_exit_3_loss: 0.4674 - val_output_main_accuracy: 0.8814 - val_output_main_loss: 0.4334 - learning_rate: 6.2500e-05
# Epoch 56/300
# 704/704 - 40s - 57ms/step - loss: 0.1774 - output_exit_1_accuracy: 0.9878 - output_exit_1_loss: 0.0884 - output_exit_2_accuracy: 0.9599 - output_exit_2_loss: 0.1280 - output_exit_3_accuracy: 0.9796 - output_exit_3_loss: 0.0611 - output_main_accuracy: 0.9626 - output_main_loss: 0.1062 - val_loss: 0.8109 - val_output_exit_1_accuracy: 0.6666 - val_output_exit_1_loss: 1.6352 - val_output_exit_2_accuracy: 0.8168 - val_output_exit_2_loss: 0.6522 - val_output_exit_3_accuracy: 0.8682 - val_output_exit_3_loss: 0.4762 - val_output_main_accuracy: 0.8806 - val_output_main_loss: 0.4479 - learning_rate: 6.2500e-05
# Epoch 57/300
# 704/704 - 41s - 58ms/step - loss: 0.1743 - output_exit_1_accuracy: 0.9889 - output_exit_1_loss: 0.0867 - output_exit_2_accuracy: 0.9605 - output_exit_2_loss: 0.1261 - output_exit_3_accuracy: 0.9824 - output_exit_3_loss: 0.0586 - output_main_accuracy: 0.9629 - output_main_loss: 0.1026 - val_loss: 0.7876 - val_output_exit_1_accuracy: 0.6628 - val_output_exit_1_loss: 1.6358 - val_output_exit_2_accuracy: 0.8160 - val_output_exit_2_loss: 0.6443 - val_output_exit_3_accuracy: 0.8744 - val_output_exit_3_loss: 0.4518 - val_output_main_accuracy: 0.8880 - val_output_main_loss: 0.4130 - learning_rate: 6.2500e-05
# Epoch 58/300
# 704/704 - 42s - 59ms/step - loss: 0.1668 - output_exit_1_accuracy: 0.9903 - output_exit_1_loss: 0.0812 - output_exit_2_accuracy: 0.9642 - output_exit_2_loss: 0.1191 - output_exit_3_accuracy: 0.9839 - output_exit_3_loss: 0.0538 - output_main_accuracy: 0.9663 - output_main_loss: 0.0939 - val_loss: 0.7970 - val_output_exit_1_accuracy: 0.6642 - val_output_exit_1_loss: 1.6431 - val_output_exit_2_accuracy: 0.8180 - val_output_exit_2_loss: 0.6459 - val_output_exit_3_accuracy: 0.8768 - val_output_exit_3_loss: 0.4585 - val_output_main_accuracy: 0.8866 - val_output_main_loss: 0.4299 - learning_rate: 3.1250e-05
# Epoch 59/300
# 704/704 - 41s - 58ms/step - loss: 0.1666 - output_exit_1_accuracy: 0.9907 - output_exit_1_loss: 0.0806 - output_exit_2_accuracy: 0.9638 - output_exit_2_loss: 0.1188 - output_exit_3_accuracy: 0.9841 - output_exit_3_loss: 0.0535 - output_main_accuracy: 0.9663 - output_main_loss: 0.0950 - val_loss: 0.7923 - val_output_exit_1_accuracy: 0.6628 - val_output_exit_1_loss: 1.6454 - val_output_exit_2_accuracy: 0.8222 - val_output_exit_2_loss: 0.6349 - val_output_exit_3_accuracy: 0.8740 - val_output_exit_3_loss: 0.4546 - val_output_main_accuracy: 0.8854 - val_output_main_loss: 0.4241 - learning_rate: 3.1250e-05
# Epoch 60/300
# 704/704 - 41s - 58ms/step - loss: 0.1651 - output_exit_1_accuracy: 0.9912 - output_exit_1_loss: 0.0799 - output_exit_2_accuracy: 0.9635 - output_exit_2_loss: 0.1190 - output_exit_3_accuracy: 0.9838 - output_exit_3_loss: 0.0533 - output_main_accuracy: 0.9683 - output_main_loss: 0.0919 - val_loss: 0.7957 - val_output_exit_1_accuracy: 0.6646 - val_output_exit_1_loss: 1.6427 - val_output_exit_2_accuracy: 0.8216 - val_output_exit_2_loss: 0.6389 - val_output_exit_3_accuracy: 0.8738 - val_output_exit_3_loss: 0.4570 - val_output_main_accuracy: 0.8870 - val_output_main_loss: 0.4300 - learning_rate: 3.1250e-05
# Epoch 61/300
# 704/704 - 40s - 57ms/step - loss: 0.1624 - output_exit_1_accuracy: 0.9914 - output_exit_1_loss: 0.0788 - output_exit_2_accuracy: 0.9631 - output_exit_2_loss: 0.1182 - output_exit_3_accuracy: 0.9840 - output_exit_3_loss: 0.0530 - output_main_accuracy: 0.9694 - output_main_loss: 0.0869 - val_loss: 0.7941 - val_output_exit_1_accuracy: 0.6666 - val_output_exit_1_loss: 1.6473 - val_output_exit_2_accuracy: 0.8216 - val_output_exit_2_loss: 0.6396 - val_output_exit_3_accuracy: 0.8746 - val_output_exit_3_loss: 0.4546 - val_output_main_accuracy: 0.8860 - val_output_main_loss: 0.4260 - learning_rate: 3.1250e-05
# Epoch 62/300
# 704/704 - 41s - 58ms/step - loss: 0.1629 - output_exit_1_accuracy: 0.9918 - output_exit_1_loss: 0.0786 - output_exit_2_accuracy: 0.9643 - output_exit_2_loss: 0.1172 - output_exit_3_accuracy: 0.9838 - output_exit_3_loss: 0.0539 - output_main_accuracy: 0.9673 - output_main_loss: 0.0892 - val_loss: 0.7938 - val_output_exit_1_accuracy: 0.6644 - val_output_exit_1_loss: 1.6547 - val_output_exit_2_accuracy: 0.8236 - val_output_exit_2_loss: 0.6368 - val_output_exit_3_accuracy: 0.8726 - val_output_exit_3_loss: 0.4520 - val_output_main_accuracy: 0.8844 - val_output_main_loss: 0.4252 - learning_rate: 3.1250e-05
# Epoch 63/300
# 704/704 - 38s - 54ms/step - loss: 0.1599 - output_exit_1_accuracy: 0.9918 - output_exit_1_loss: 0.0780 - output_exit_2_accuracy: 0.9649 - output_exit_2_loss: 0.1164 - output_exit_3_accuracy: 0.9845 - output_exit_3_loss: 0.0506 - output_main_accuracy: 0.9702 - output_main_loss: 0.0851 - val_loss: 0.8078 - val_output_exit_1_accuracy: 0.6644 - val_output_exit_1_loss: 1.6606 - val_output_exit_2_accuracy: 0.8172 - val_output_exit_2_loss: 0.6506 - val_output_exit_3_accuracy: 0.8708 - val_output_exit_3_loss: 0.4682 - val_output_main_accuracy: 0.8816 - val_output_main_loss: 0.4441 - learning_rate: 3.1250e-05
# Epoch 64/300
# 704/704 - 38s - 54ms/step - loss: 0.1607 - output_exit_1_accuracy: 0.9915 - output_exit_1_loss: 0.0778 - output_exit_2_accuracy: 0.9639 - output_exit_2_loss: 0.1174 - output_exit_3_accuracy: 0.9848 - output_exit_3_loss: 0.0517 - output_main_accuracy: 0.9702 - output_main_loss: 0.0879 - val_loss: 0.8048 - val_output_exit_1_accuracy: 0.6656 - val_output_exit_1_loss: 1.6634 - val_output_exit_2_accuracy: 0.8192 - val_output_exit_2_loss: 0.6490 - val_output_exit_3_accuracy: 0.8748 - val_output_exit_3_loss: 0.4595 - val_output_main_accuracy: 0.8872 - val_output_main_loss: 0.4416 - learning_rate: 3.1250e-05
# Epoch 65/300
# 704/704 - 39s - 55ms/step - loss: 0.1586 - output_exit_1_accuracy: 0.9920 - output_exit_1_loss: 0.0765 - output_exit_2_accuracy: 0.9661 - output_exit_2_loss: 0.1155 - output_exit_3_accuracy: 0.9843 - output_exit_3_loss: 0.0513 - output_main_accuracy: 0.9709 - output_main_loss: 0.0849 - val_loss: 0.7984 - val_output_exit_1_accuracy: 0.6654 - val_output_exit_1_loss: 1.6619 - val_output_exit_2_accuracy: 0.8230 - val_output_exit_2_loss: 0.6391 - val_output_exit_3_accuracy: 0.8740 - val_output_exit_3_loss: 0.4598 - val_output_main_accuracy: 0.8900 - val_output_main_loss: 0.4300 - learning_rate: 3.1250e-05
# Epoch 66/300
# 704/704 - 39s - 55ms/step - loss: 0.1576 - output_exit_1_accuracy: 0.9915 - output_exit_1_loss: 0.0765 - output_exit_2_accuracy: 0.9652 - output_exit_2_loss: 0.1145 - output_exit_3_accuracy: 0.9848 - output_exit_3_loss: 0.0498 - output_main_accuracy: 0.9702 - output_main_loss: 0.0839 - val_loss: 0.8011 - val_output_exit_1_accuracy: 0.6642 - val_output_exit_1_loss: 1.6719 - val_output_exit_2_accuracy: 0.8228 - val_output_exit_2_loss: 0.6423 - val_output_exit_3_accuracy: 0.8748 - val_output_exit_3_loss: 0.4603 - val_output_main_accuracy: 0.8880 - val_output_main_loss: 0.4332 - learning_rate: 3.1250e-05
# Epoch 67/300
# 704/704 - 38s - 55ms/step - loss: 0.1586 - output_exit_1_accuracy: 0.9920 - output_exit_1_loss: 0.0764 - output_exit_2_accuracy: 0.9641 - output_exit_2_loss: 0.1150 - output_exit_3_accuracy: 0.9845 - output_exit_3_loss: 0.0509 - output_main_accuracy: 0.9696 - output_main_loss: 0.0866 - val_loss: 0.8084 - val_output_exit_1_accuracy: 0.6636 - val_output_exit_1_loss: 1.6750 - val_output_exit_2_accuracy: 0.8210 - val_output_exit_2_loss: 0.6437 - val_output_exit_3_accuracy: 0.8714 - val_output_exit_3_loss: 0.4663 - val_output_main_accuracy: 0.8856 - val_output_main_loss: 0.4447 - learning_rate: 3.1250e-05
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 27.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modelo Early-Exit treinado e salvo.

# %%
results = model.evaluate(X_test, y_test, verbose=1)

print('\nTotal Loss:', results[0])
print('Exit 1 Accuracy:', results[2])
print('Exit 2 Accuracy:', results[4])
print('Exit 3 Accuracy:', results[6])
print('Main Output Accuracy:', results[8])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.7416 - output_exit_1_accuracy: 0.6633 - output_exit_1_loss: 1.3031 - output_exit_2_accuracy: 0.8074 - output_exit_2_loss: 0.6206 - output_exit_3_accuracy: 0.8605 - output_exit_3_loss: 0.4582 - output_main_accuracy: 0.8654 - output_main_loss: 0.4138
#
# Total Loss: 0.7415618896484375
# Exit 1 Accuracy: 0.6205655336380005
# Exit 2 Accuracy: 0.4137953519821167
# Exit 3 Accuracy: 0.8073999881744385
# Main Output Accuracy: 0.8654000163078308

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

url = "https://raw.githubusercontent.com/FarzadNekouee/Keras-CIFAR10-CNN-Model/master/truck_sample.png"
resp = urllib.request.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

original_image = image.copy()

image = cv2.resize(image, (32,32))
image = image.astype('float32')
image = (image-mean)/(std+1e-7)

input_image = image.reshape((1, 32, 32, 3))

predictions = model.predict(input_image)
main_prediction = predictions[-1]
predicted_class = main_prediction.argmax()
print('Predicted class (Main Exit): ', class_names[predicted_class])

plt.imshow(original_image)
plt.title(f'Imagem Original - Predição Principal: {class_names[predicted_class]}')
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted class (Main Exit):  truck

# %%
raw_image = r"C:\Users\joaov_zm1q2wh\python\etsai\week_5\code\data\binary_classification\images\test\dog\dog.1364.jpg" 
image = np.asarray(bytearray(raw_image.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 raw_image = r"C:\Users\joaov_zm1q2wh\python\etsai\week_5\code\data\binary_classification\images\test\dog\dog.1364.jpg"
# ----> 2 image = np.asarray(bytearray(raw_image.read()), dtype="uint8")
#       3 image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)
#       4 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#
# AttributeError: 'str' object has no attribute 'read'

# %%
def make_gradcam_heatmap_multi_output(img_array, model, last_conv_layer_name, output_index, pred_index=None):
   
    grad_model = tf.keras.models.Model(
        [model.inputs],
        [model.get_layer(last_conv_layer_name).output, model.outputs[output_index]]
    )

    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def display_gradcam(img, heatmap, alpha=0.4):
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    superimposed_img = np.uint8(img)
    superimposed_img = cv2.addWeighted(superimposed_img, 1 - alpha, heatmap, alpha, 0)
    return superimposed_img, heatmap

conv_layer_names = [
    'conv1_2', 
    'conv2_2', 
    'conv3_2', 
    'conv4_2'
]

main_output_index = 3

num_layers = len(conv_layer_names)
fig, axes = plt.subplots(2, num_layers, figsize=(4 * num_layers, 8))
fig.suptitle(f'Mapas de Saliência Grad-CAM para a Classe: {class_names[predicted_class]} (Saída Principal)', fontsize=16)

for i, layer_name in enumerate(conv_layer_names):
    heatmap = make_gradcam_heatmap_multi_output(
        input_image, model, layer_name, main_output_index, predicted_class
    )
    
    axes[0, i].matshow(heatmap)
    axes[0, i].set_title(f'Mapa de Calor - {layer_name}', fontsize=10)
    axes[0, i].axis('off')
    
    superimposed_img, _ = display_gradcam(original_image, heatmap)
    
    axes[1, i].imshow(superimposed_img)
    axes[1, i].set_title(f'Sobreposição - {layer_name}', fontsize=10)
    axes[1, i].axis('off')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# Da última vez que fiz essa merda, na verdade foi um plot das Ativações dos FILTROS, onde eu mostrava a saída bruta de cada filtro em cada camada. O resultado são centenas de imagens em escala de cinza, uma para cada filtro.
#
# Dessa vez minha ideia foi fazer o Mapa de Saliência da IMAGEM usando o algoritmo Grad-CAM, que agrega a informação de todos os filtros de uma camada para gerar um único mapa de saliência, destacando as regiões da imagem de entrada que mais contribuíram para a predição da classe alvo. O resultado é um mapa de calor que é sobreposto à imagem original.
